# %% [markdown]
# # NBA to NCCA Data Entity Resolution

# %%
import pandas as pd
import string
import numpy as np
from fuzzywuzzy import fuzz
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import pairwise_distances

# %% [markdown]
# ## Utility Functions

# %%
def clean_text(text):
    clean_text = text.translate(str.maketrans('', '', string.punctuation)).upper()
    clean_text = ' '.join(clean_text.split())
    return clean_text

def token_sort_ratio(str1, str2):
    return fuzz.token_sort_ratio(str1, str2)

# %% [markdown]
# ## Load/Explore NBA data

# %%
nba_data = pd.read_csv('./nba_player_avgs_2008-2025.csv')

# %%
nba_data.head()
# Out:
#    Unnamed: 0  personId     season  gameId  numMinutes     points   assists  \
# 0           0        87  2008-2009       9   10.333333   1.777778  0.000000
# 1           1       255  2008-2009      82   29.341463  12.012195  2.268293
# 2           2       255  2009-2010      81   29.543210  11.259259  2.382716
# 3           3       255  2010-2011      80   29.587500  13.200000  2.500000
# 4           4       255  2011-2012      49   27.612245  10.183673  2.183673
#
#      blocks    steals  fieldGoalsAttempted  ...  lastAttended  country  \
# 0  1.222222  0.000000             1.444444  ...    Georgetown    Congo
# 1  0.658537  1.097561             9.085366  ...          Duke      USA
# 2  0.444444  0.740741             8.679012  ...          Duke      USA
# 3  0.437500  0.800000            10.312500  ...          Duke      USA
# 4  0.591837  0.836735             9.204082  ...          Duke      USA
#
#    height  bodyWeight  guard  forward  center  draftYear  draftRound  \
# 0    86.0       260.0  False    False    True     1991.0         1.0
# 1    80.0       225.0  False     True   False     1994.0         1.0
# 2    80.0       225.0  False     True   False     1994.0         1.0
# 3    80.0       225.0  False     True   False     1994.0         1.0
# 4    80.0       225.0  False     True   False     1994.0         1.0
#
#    draftNumber
# 0          4.0
# 1          3.0
# 2          3.0
# 3          3.0
# 4          3.0
#
# [5 rows x 37 columns]

# %%
nba_data.columns
# Out:
# Index(['Unnamed: 0', 'personId', 'season', 'gameId', 'numMinutes', 'points',
#        'assists', 'blocks', 'steals', 'fieldGoalsAttempted', 'fieldGoalsMade',
#        'fieldGoalsPercentage', 'threePointersAttempted', 'threePointersMade',
#        'threePointersPercentage', 'freeThrowsAttempted', 'freeThrowsMade',
#        'freeThrowsPercentage', 'reboundsDefensive', 'reboundsOffensive',
#        'reboundsTotal', 'foulsPersonal', 'turnovers', 'plusMinusPoints',
#        'firstName', 'lastName', 'birthdate', 'lastAttended', 'country',
#        'height', 'bodyWeight', 'guard', 'forward', 'center', 'draftYear',
#        'draftRound', 'draftNumber'],
#       dtype='object')

# %%
len(nba_data)
# Out:
# 8617

# %%
len(nba_data.drop_duplicates(subset = ['personId', 'season']))
# Out:
# 8617

# %%
# need to aggregate nba season data
# duplicate personIds for multiple seasons
len(nba_data.drop_duplicates(subset = ['personId']))
# Out:
# 1921

# %% [markdown]
# ## Load/Explore NCAA Data

# %%
ncaa_2024data = pd.read_csv('./trank_data_2024.csv')

# %%
ncaa_2024data.head()
# Out:
#        player_name                    team  conf  GP  Min_per   ORtg   usg  \
# 0   DeJuan Clayton               Manhattan  MAAC   2      4.3   88.3  27.8
# 1       Seth Towns                  Howard  MEAC  30     73.4  108.2  22.1
# 2   Terrence Lewis           Grambling St.  SWAC  20     26.9  116.1  19.0
# 3  Austin Williams                 Rutgers   B10  26     32.1   85.7  16.5
# 4     Avery Wilson  Southeastern Louisiana  Slnd  29     27.8   87.8  16.7
#
#     eFG  TS_per  ORB_per  ...     ogbpm     dgbpm    oreb    dreb    treb  \
# 0  47.4   49.27      0.0  ... -3.001390 -4.186660  0.0000  3.5000  3.5000
# 1  45.2   52.19      4.2  ...  0.710116 -1.209580  1.1562  5.3750  6.5312
# 2  63.9   64.03      3.2  ...  3.847560 -0.389764  0.6522  1.6087  2.2609
# 3  50.0   48.56      5.3  ... -3.757340  2.324820  0.8462  1.8077  2.6538
# 4  45.1   47.15      4.1  ... -5.712040 -0.732916  0.3438  1.0000  1.3438
#
#       ast     stl     blk      pts  pos_class
# 0  3.0000  0.0000  0.0000  11.0000     Wing G
# 1  2.4688  0.9688  0.4375  14.1250  Stretch 4
# 2  0.3478  0.4783  0.1739   7.9130     Wing G
# 3  0.6154  0.4615  0.2692   3.9615     Wing G
# 4  0.7812  0.4062  0.0938   3.1875     Wing G
#
# [5 rows x 65 columns]

# %%
ncaa_2024data.columns
# Out:
# Index(['player_name', 'team', 'conf', 'GP', 'Min_per', 'ORtg', 'usg', 'eFG',
#        'TS_per', 'ORB_per', 'DRB_per', 'AST_per', 'TO_per', 'FTM', 'FTA',
#        'FT_per', 'twoPM', 'twoPA', 'twoP_per', 'TPM', 'TPA', 'TP_per',
#        'blk_per', 'stl_per', 'ftr', 'yr', 'ht', 'num', 'porpag', 'adjoe',
#        'pfr', 'year', 'pid', 'type', 'Rec Rank', 'ast/tov', 'rimmade',
#        'rimmade+rimmiss', 'midmade', 'midmade+midmiss',
#        'rimmade/(rimmade+rimmiss)', 'midmade/(midmade+midmiss)', 'dunksmade',
#        'dunksmiss+dunksmade', 'dunksmade/(dunksmade+dunksmiss)', 'pick',
#        'drtg', 'adrtg', 'dporpag', 'stops', 'bpm', 'obpm', 'dbpm', 'gbpm',
#        'mp', 'ogbpm', 'dgbpm', 'oreb', 'dreb', 'treb', 'ast', 'stl', 'blk',
#        'pts', 'pos_class'],
#       dtype='object')

# %%
# load aggregated college data
player_data_college = pd.read_csv('./player_data_college.csv')

# %%
player_data_college.head()
# Out:
#        player_name                 team  height  min_year  max_year pos_class  \
# 0   A'Jahni Levias         North Dakota  198.12      2023      2023    Wing G
# 1  A'Torey Everett        Tennessee St.  193.04      2017      2017   Combo G
# 2    A'Torri Shine        Grambling St.  198.12      2014      2015    Wing G
# 3  A'Uston Calhoun        Bowling Green  200.66      2013      2013    Wing F
# 4    A'lahn Sumler  Charleston Southern  193.04      2024      2024   Combo G
#
#             type  avg_box_plus_minus  avg_box_offensive_plus_minus  \
# 0    Vallejo, CA           -5.324950                     -2.808850
# 1     Dallas, TX           -6.374510                     -4.922240
# 2            NaN           -6.934815                     -2.114325
# 3            NaN           -3.123610                     -1.285750
# 4  Waterbury, CT           -0.456725                      0.617211
#
#    avg_box_defensive_plus_minus  ...  avg_offensive_reb  avg_defensive_reb  \
# 0                     -2.516100  ...           14.66181           28.46250
# 1                     -1.452270  ...            2.37500           14.25000
# 2                     -4.820495  ...          180.00152          428.27386
# 3                     -1.837860  ...          189.94946          399.44946
# 4                     -1.073940  ...           43.14432          185.26592
#
#    avg_total_reb  avg_assists  avg_steals  avg_blocks  avg_points_scored  \
# 0       43.12431     14.66181     8.62569     0.00000           85.38750
# 1       16.62500     13.45770     1.58270     0.79230           45.91730
# 2      608.27538    151.07596   105.84388    34.32940         2066.74504
# 3      589.39054     67.04000    30.72946    39.10946         1276.55054
# 4      228.41024    119.28352    68.52160    20.30624         1048.16704
#
#    avg_freethrow_pct  avg_2p_pct  avg_3p_pct
# 0           0.687500    0.457143    0.323529
# 1           0.782609    0.300000    0.571429
# 2           0.769133    0.449183    0.308231
# 3           0.796460    0.461310    0.351852
# 4           0.718310    0.454054    0.339286
#
# [5 rows x 42 columns]

# %%
player_data_college.columns
# Out:
# Index(['player_name', 'team', 'height', 'min_year', 'max_year', 'pos_class',
#        'type', 'avg_box_plus_minus', 'avg_box_offensive_plus_minus',
#        'avg_box_defensive_plus_minus', 'avg_global_plus_minus',
#        'avg_offensive_global_plus_minus', 'avg_defensive_global_plus_minus',
#        'total_min_per', 'avg_offensive_rating', 'avg_defensive_rating',
#        'avg_defensive_points_ov_replacement', 'avg_defensive_stop',
#        'avg_usage_rate', 'avg_effective_field_goal_pct', 'avg_shooting_pct',
#        'avg_offensive_rebound_pct', 'avg_defensive_rebound_pct',
#        'avg_freethrow_made', 'avg_freethrow_attempted', 'avg_2p_made',
#        'avg_2p_attempted', 'avg_3p_made', 'avg_3p_attempted', 'avg_block_pct',
#        'avg_steal_pct', 'avg_pick', 'avg_offensive_reb', 'avg_defensive_reb',
#        'avg_total_reb', 'avg_assists', 'avg_steals', 'avg_blocks',
#        'avg_points_scored', 'avg_freethrow_pct', 'avg_2p_pct', 'avg_3p_pct'],
#       dtype='object')

# %%
len(player_data_college)
# Out:
# 39094

# %%
# unique on player name and team. 
# may have some dupes for cases where players have transfered. not a huge deal
len(player_data_college.drop_duplicates(subset = ['player_name', 'team']))
# Out:
# 39094

# %% [markdown]
# ## Generate unique IDs

# %%
nba_data['nba_id'] = nba_data['personId']
nba_data.drop('personId', axis = 1, inplace = True)
nba_data.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
nba_data.to_csv('./resolved_data/nba_player_season_avgs_2008-2025.csv', index = False)

# %%
player_data_college['ncaa_id'] = pd.RangeIndex(start = 1, stop = len(player_data_college) + 1)

# %%
player_data_college.head()
# Out:
#        player_name                 team  height  min_year  max_year pos_class  \
# 0   A'Jahni Levias         North Dakota  198.12      2023      2023    Wing G
# 1  A'Torey Everett        Tennessee St.  193.04      2017      2017   Combo G
# 2    A'Torri Shine        Grambling St.  198.12      2014      2015    Wing G
# 3  A'Uston Calhoun        Bowling Green  200.66      2013      2013    Wing F
# 4    A'lahn Sumler  Charleston Southern  193.04      2024      2024   Combo G
#
#             type  avg_box_plus_minus  avg_box_offensive_plus_minus  \
# 0    Vallejo, CA           -5.324950                     -2.808850
# 1     Dallas, TX           -6.374510                     -4.922240
# 2            NaN           -6.934815                     -2.114325
# 3            NaN           -3.123610                     -1.285750
# 4  Waterbury, CT           -0.456725                      0.617211
#
#    avg_box_defensive_plus_minus  ...  avg_defensive_reb  avg_total_reb  \
# 0                     -2.516100  ...           28.46250       43.12431
# 1                     -1.452270  ...           14.25000       16.62500
# 2                     -4.820495  ...          428.27386      608.27538
# 3                     -1.837860  ...          399.44946      589.39054
# 4                     -1.073940  ...          185.26592      228.41024
#
#    avg_assists  avg_steals  avg_blocks  avg_points_scored  avg_freethrow_pct  \
# 0     14.66181     8.62569     0.00000           85.38750           0.687500
# 1     13.45770     1.58270     0.79230           45.91730           0.782609
# 2    151.07596   105.84388    34.32940         2066.74504           0.769133
# 3     67.04000    30.72946    39.10946         1276.55054           0.796460
# 4    119.28352    68.52160    20.30624         1048.16704           0.718310
#
#    avg_2p_pct  avg_3p_pct  ncaa_id
# 0    0.457143    0.323529        1
# 1    0.300000    0.571429        2
# 2    0.449183    0.308231        3
# 3    0.461310    0.351852        4
# 4    0.454054    0.339286        5
#
# [5 rows x 43 columns]

# %%
player_data_college.to_csv('./resolved_data/player_data_college.csv', index = False)

# %% [markdown]
# ## Execute Entity Resolution
#
# - resolve nba_ids to ncaa_ids
# - first block on college team team name
# - then try comparing max year and draft year (draft year >= max year) for a block

# %% [markdown]
# ### Pull Relevant Fields

# %%
nba_identifiers = [
    'nba_id',
    'firstName',
    'lastName',
    'birthdate',
    'lastAttended',
    'country',
    'draftYear',
    'draftRound',
    'draftNumber',
]

# only get unique nba ids
nba_er_data = nba_data[nba_identifiers].drop_duplicates(subset = ['nba_id']).replace({np.nan: None})
nba_er_data = nba_er_data[nba_er_data['lastAttended'].notnull()]

# %%
len(nba_er_data)
# Out:
# 1440

# %%
ncaa_identifiers = [
    'ncaa_id',
    'player_name', 
    'team', 
    'min_year', 
    'max_year'
]

ncaa_er_data = player_data_college[ncaa_identifiers].drop_duplicates(subset = ['ncaa_id'])

# %% [markdown]
# ### Clean Fields used for ER

# %%
# nba player name
nba_er_data['full_name'] = nba_er_data['firstName'] + ' ' + nba_er_data['lastName']
nba_er_data['clean_full_name'] = nba_er_data['full_name'].apply(clean_text)

# %%
# nba player name
ncaa_er_data['clean_player_name'] = ncaa_er_data['player_name'].apply(clean_text)

# %%
# save er data for review
nba_er_data.to_csv('resolved_data/nba_er_data.csv', index = False)
ncaa_er_data.to_csv('resolved_data/ncaa_er_data.csv', index = False)

# %%
# clean team names
nba_er_data['clean_lastAttended'] = nba_er_data['lastAttended'].apply(clean_text)
ncaa_er_data['clean_team'] = ncaa_er_data['team'].apply(clean_text)

# %%
nba_er_data.head()
# Out:
#     nba_id  firstName lastName   birthdate     lastAttended country draftYear  \
# 0       87    Dikembe  Mutombo  1966-06-25       Georgetown   Congo      1991
# 1      255      Grant     Hill  1972-10-05             Duke     USA      1994
# 6      283    Lindsey   Hunter  1970-12-03    Jackson State     USA      1993
# 8      406  Shaquille   O'Neal  1972-03-06  Louisiana State     USA      1992
# 11     436      Juwan   Howard  1973-02-07         Michigan     USA      1994
#
#    draftRound draftNumber         full_name  clean_full_name  \
# 0           1           4   Dikembe Mutombo  DIKEMBE MUTOMBO
# 1           1           3        Grant Hill       GRANT HILL
# 6           1          10    Lindsey Hunter   LINDSEY HUNTER
# 8           1           1  Shaquille O'Neal  SHAQUILLE ONEAL
# 11          1           5      Juwan Howard     JUWAN HOWARD
#
#    clean_lastAttended
# 0          GEORGETOWN
# 1                DUKE
# 6       JACKSON STATE
# 8     LOUISIANA STATE
# 11           MICHIGAN

# %%
# check if draft year is null 
nba_er_data[nba_er_data['draftYear'].isnull()]
# Out:
# Empty DataFrame
# Columns: [nba_id, firstName, lastName, birthdate, lastAttended, country, draftYear, draftRound, draftNumber, full_name, clean_full_name, clean_lastAttended]
# Index: []

# %%
ncaa_er_data.head()
# Out:
#    ncaa_id      player_name                 team  min_year  max_year  \
# 0        1   A'Jahni Levias         North Dakota      2023      2023
# 1        2  A'Torey Everett        Tennessee St.      2017      2017
# 2        3    A'Torri Shine        Grambling St.      2014      2015
# 3        4  A'Uston Calhoun        Bowling Green      2013      2013
# 4        5    A'lahn Sumler  Charleston Southern      2024      2024
#
#   clean_player_name           clean_team
# 0     AJAHNI LEVIAS         NORTH DAKOTA
# 1    ATOREY EVERETT         TENNESSEE ST
# 2      ATORRI SHINE         GRAMBLING ST
# 3    AUSTON CALHOUN        BOWLING GREEN
# 4      ALAHN SUMLER  CHARLESTON SOUTHERN

# %%
# check if max_year is ever null
ncaa_er_data[ncaa_er_data['max_year'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ncaa_id, player_name, team, min_year, max_year, clean_player_name, clean_team]
# Index: []

# %% [markdown]
# ### Execute College Name Tocken Block
# - ensure that draftYear is greater than or equal to max year
# - drop cases where team name is less than 4 characters (matching on acronyms introduces too much noise)

# %%
# get nba team tokens
nba_er_data['college_token'] = nba_er_data['clean_lastAttended'].str.split()
nba_er_data_exploded = nba_er_data.explode('college_token')
nba_er_data_exploded = nba_er_data_exploded[nba_er_data_exploded['college_token'].str.len() >= 4]

# %%
nba_er_data_exploded.head()
# Out:
#    nba_id  firstName lastName   birthdate     lastAttended country draftYear  \
# 0      87    Dikembe  Mutombo  1966-06-25       Georgetown   Congo      1991
# 1     255      Grant     Hill  1972-10-05             Duke     USA      1994
# 6     283    Lindsey   Hunter  1970-12-03    Jackson State     USA      1993
# 6     283    Lindsey   Hunter  1970-12-03    Jackson State     USA      1993
# 8     406  Shaquille   O'Neal  1972-03-06  Louisiana State     USA      1992
#
#   draftRound draftNumber         full_name  clean_full_name  \
# 0          1           4   Dikembe Mutombo  DIKEMBE MUTOMBO
# 1          1           3        Grant Hill       GRANT HILL
# 6          1          10    Lindsey Hunter   LINDSEY HUNTER
# 6          1          10    Lindsey Hunter   LINDSEY HUNTER
# 8          1           1  Shaquille O'Neal  SHAQUILLE ONEAL
#
#   clean_lastAttended college_token
# 0         GEORGETOWN    GEORGETOWN
# 1               DUKE          DUKE
# 6      JACKSON STATE       JACKSON
# 6      JACKSON STATE         STATE
# 8    LOUISIANA STATE     LOUISIANA

# %%
len(nba_er_data_exploded)
# Out:
# 1956

# %%
# get ncaa team tokens
ncaa_er_data['college_token'] = ncaa_er_data['clean_team'].str.split()
ncaa_er_data_exploded = ncaa_er_data.explode('college_token')
ncaa_er_data_exploded = ncaa_er_data_exploded[ncaa_er_data_exploded['college_token'].str.len() >= 4]

# %%
ncaa_er_data_exploded.head()
# Out:
#    ncaa_id      player_name           team  min_year  max_year  \
# 0        1   A'Jahni Levias   North Dakota      2023      2023
# 0        1   A'Jahni Levias   North Dakota      2023      2023
# 1        2  A'Torey Everett  Tennessee St.      2017      2017
# 2        3    A'Torri Shine  Grambling St.      2014      2015
# 3        4  A'Uston Calhoun  Bowling Green      2013      2013
#
#   clean_player_name     clean_team college_token
# 0     AJAHNI LEVIAS   NORTH DAKOTA         NORTH
# 0     AJAHNI LEVIAS   NORTH DAKOTA        DAKOTA
# 1    ATOREY EVERETT   TENNESSEE ST     TENNESSEE
# 2      ATORRI SHINE   GRAMBLING ST     GRAMBLING
# 3    AUSTON CALHOUN  BOWLING GREEN       BOWLING

# %%
len(ncaa_er_data_exploded)
# Out:
# 49952

# %%
len(ncaa_er_data)
# Out:
# 39094

# %%
# execute block
college_token_block = pd.merge(nba_er_data_exploded, ncaa_er_data_exploded, on = 'college_token', how = 'inner')

# %%
college_token_block_filtered = college_token_block[college_token_block['draftYear'] >= college_token_block['max_year']].copy()

# %%
len(college_token_block)
# Out:
# 478116

# %%
len(college_token_block_filtered)
# Out:
# 57521

# %%
college_token_block.to_csv('./resolved_data/college_token_block_filtered.csv', index = False)

# %% [markdown]
# ### Execute Fuzzy Name Match
# - fuzzy name match threshold of 85

# %%
college_token_block_filtered['fuzzy_name_score'] = college_token_block_filtered.apply(lambda r: token_sort_ratio(r['clean_full_name'], r['clean_player_name']), axis = 1)

# %%
college_token_block_filtered.head()
# Out:
#      nba_id firstName    lastName   birthdate lastAttended country draftYear  \
# 585  202328      Greg      Monroe  1990-06-04   Georgetown     USA      2010
# 631  202328      Greg      Monroe  1990-06-04   Georgetown     USA      2010
# 646  202328      Greg      Monroe  1990-06-04   Georgetown     USA      2010
# 995  203490      Otto  Porter Jr.  1993-06-03   Georgetown     USA      2013
# 999  203490      Otto  Porter Jr.  1993-06-03   Georgetown     USA      2013
#
#     draftRound draftNumber        full_name  ... clean_lastAttended  \
# 585          1           7      Greg Monroe  ...         GEORGETOWN
# 631          1           7      Greg Monroe  ...         GEORGETOWN
# 646          1           7      Greg Monroe  ...         GEORGETOWN
# 995          1           3  Otto Porter Jr.  ...         GEORGETOWN
# 999          1           3  Otto Porter Jr.  ...         GEORGETOWN
#
#     college_token ncaa_id          player_name        team min_year  max_year  \
# 585    GEORGETOWN   14236          Greg Monroe  Georgetown     2010      2010
# 631    GEORGETOWN   29300  Nikita Mescheriakov  Georgetown     2010      2010
# 646    GEORGETOWN   34406       Stephen Stepka  Georgetown     2010      2010
# 995    GEORGETOWN    2779       Austin Freeman  Georgetown     2010      2011
# 999    GEORGETOWN    3950       Brandon Bolden  Georgetown     2013      2013
#
#        clean_player_name  clean_team fuzzy_name_score
# 585          GREG MONROE  GEORGETOWN              100
# 631  NIKITA MESCHERIAKOV  GEORGETOWN               20
# 646       STEPHEN STEPKA  GEORGETOWN               24
# 995       AUSTIN FREEMAN  GEORGETOWN               14
# 999       BRANDON BOLDEN  GEORGETOWN               14
#
# [5 rows x 21 columns]

# %%
college_token_block_fuzzy = college_token_block_filtered[college_token_block_filtered['fuzzy_name_score'] >= 85.0]

# %%
college_token_block_fuzzy.to_csv('./resolved_data/college_token_block_fuzzy.csv')

# %%
idx_max_scores = college_token_block_fuzzy.groupby('nba_id')['fuzzy_name_score'].idxmax()
nba_ncaa_matches = college_token_block_fuzzy.loc[idx_max_scores]

# %%
nba_ncaa_matches.to_csv('./resolved_data/nba_ncaa_matches.csv', index = False)

# %%
len(nba_ncaa_matches)
# Out:
# 402

# %%
len(nba_ncaa_matches.drop_duplicates(subset = ['ncaa_id']))
# Out:
# 402

# %% [markdown]
# ### Get ER Match Rates

# %%
len(nba_er_data)
# Out:
# 1440

# %%
nba_er_data.head()
# Out:
#     nba_id  firstName lastName   birthdate     lastAttended country draftYear  \
# 0       87    Dikembe  Mutombo  1966-06-25       Georgetown   Congo      1991
# 1      255      Grant     Hill  1972-10-05             Duke     USA      1994
# 6      283    Lindsey   Hunter  1970-12-03    Jackson State     USA      1993
# 8      406  Shaquille   O'Neal  1972-03-06  Louisiana State     USA      1992
# 11     436      Juwan   Howard  1973-02-07         Michigan     USA      1994
#
#    draftRound draftNumber         full_name  clean_full_name  \
# 0           1           4   Dikembe Mutombo  DIKEMBE MUTOMBO
# 1           1           3        Grant Hill       GRANT HILL
# 6           1          10    Lindsey Hunter   LINDSEY HUNTER
# 8           1           1  Shaquille O'Neal  SHAQUILLE ONEAL
# 11          1           5      Juwan Howard     JUWAN HOWARD
#
#    clean_lastAttended       college_token
# 0          GEORGETOWN        [GEORGETOWN]
# 1                DUKE              [DUKE]
# 6       JACKSON STATE    [JACKSON, STATE]
# 8     LOUISIANA STATE  [LOUISIANA, STATE]
# 11           MICHIGAN          [MICHIGAN]

# %%
nba_drafted_post_2010 = nba_er_data[nba_er_data['draftYear'] >= 2010]

# %%
nba_drafted_post_2010.head()
# Out:
#       nba_id firstName lastName   birthdate  lastAttended country draftYear  \
# 3291  202322      John     Wall  1990-09-06      Kentucky     USA      2010
# 3302  202323      Evan   Turner  1988-10-27    Ohio State     USA      2010
# 3312  202324   Derrick   Favors  1991-07-15  Georgia Tech     USA      2010
# 3324  202325    Wesley  Johnson  1987-07-11      Syracuse     USA      2010
# 3333  202326  DeMarcus  Cousins  1990-08-13      Kentucky     USA      2010
#
#      draftRound draftNumber         full_name   clean_full_name  \
# 3291          1           1         John Wall         JOHN WALL
# 3302          1           2       Evan Turner       EVAN TURNER
# 3312          1           3    Derrick Favors    DERRICK FAVORS
# 3324          1           4    Wesley Johnson    WESLEY JOHNSON
# 3333          1           5  DeMarcus Cousins  DEMARCUS COUSINS
#
#      clean_lastAttended    college_token
# 3291           KENTUCKY       [KENTUCKY]
# 3302         OHIO STATE    [OHIO, STATE]
# 3312       GEORGIA TECH  [GEORGIA, TECH]
# 3324           SYRACUSE       [SYRACUSE]
# 3333           KENTUCKY       [KENTUCKY]

# %%
len(nba_drafted_post_2010)
# Out:
# 509

# %%
print(f"Raw Match Rate for all NBA records: {round((len(nba_ncaa_matches) / len(nba_data.drop_duplicates(subset = ['nba_id']))) * 100, 3)}%")
print(f"Match Rate for NBA records with nonnull last attended (college name): {round((len(nba_ncaa_matches) / len(nba_er_data)) * 100, 3)}%")
print(f"Match Rate for NBA records with draftYear >= 2010: {round((len(nba_ncaa_matches) / len(nba_drafted_post_2010)) * 100, 3)}%")
# Out:
# Raw Match Rate for all NBA records: 20.927%
# Match Rate for NBA records with nonnull last attended (college name): 27.917%
# Match Rate for NBA records with draftYear >= 2010: 78.978%

# %% [markdown]
# ### Generate QA Review

# %%
min(nba_data['draftYear'])
# Out:
# -22.0

# %%
nba_ncaa_matches[['nba_id', 'ncaa_id']].to_csv('./resolved_data/nba_ncaa_map.csv', index = False)

# %%
nba_ncaa_matches.head()
# Out:
#         nba_id firstName lastName   birthdate  lastAttended country draftYear  \
# 332368  202322      John     Wall  1990-09-06      Kentucky     USA      2010
# 363139  202323      Evan   Turner  1988-10-27    Ohio State     USA      2010
# 176738  202324   Derrick   Favors  1991-07-15  Georgia Tech     USA      2010
# 381231  202325    Wesley  Johnson  1987-07-11      Syracuse     USA      2010
# 332700  202326  DeMarcus  Cousins  1990-08-13      Kentucky     USA      2010
#
#        draftRound draftNumber         full_name  ... clean_lastAttended  \
# 332368          1           1         John Wall  ...           KENTUCKY
# 363139          1           2       Evan Turner  ...         OHIO STATE
# 176738          1           3    Derrick Favors  ...       GEORGIA TECH
# 381231          1           4    Wesley Johnson  ...           SYRACUSE
# 332700          1           5  DeMarcus Cousins  ...           KENTUCKY
#
#        college_token ncaa_id       player_name          team min_year  \
# 332368      KENTUCKY   19599         John Wall      Kentucky     2010
# 363139          OHIO   13070       Evan Turner      Ohio St.     2010
# 176738       GEORGIA   10482    Derrick Favors  Georgia Tech     2010
# 381231      SYRACUSE   37984       Wes Johnson      Syracuse     2010
# 332700      KENTUCKY    9911  DeMarcus Cousins      Kentucky     2010
#
#         max_year  clean_player_name    clean_team fuzzy_name_score
# 332368      2010          JOHN WALL      KENTUCKY              100
# 363139      2010        EVAN TURNER       OHIO ST              100
# 176738      2010     DERRICK FAVORS  GEORGIA TECH              100
# 381231      2010        WES JOHNSON      SYRACUSE               88
# 332700      2010   DEMARCUS COUSINS      KENTUCKY              100
#
# [5 rows x 21 columns]

# %%
nba_ncaa_matches.columns
# Out:
# Index(['nba_id', 'firstName', 'lastName', 'birthdate', 'lastAttended',
#        'country', 'draftYear', 'draftRound', 'draftNumber', 'full_name',
#        'clean_full_name', 'clean_lastAttended', 'college_token', 'ncaa_id',
#        'player_name', 'team', 'min_year', 'max_year', 'clean_player_name',
#        'clean_team', 'fuzzy_name_score'],
#       dtype='object')

# %%
col_rename_dict = {
    'firstName': 'nba_first_name',
    'lastName': 'nba_last_name',
    'birthdate': 'nba_birthdate',
    'lastAttended': 'nba_college_name',
    'country': 'nba_country',
    'draftYear': 'nba_draft_year',
    'draftRound': 'nba_draft_round',
    'full_name': 'nba_full_name',
    'clean_full_name': 'nba_clean_full_name',
    'clean_lastAttended': 'nba_clean_college_name',
    'player_name': 'ncaa_full_name',
    'team': 'ncaa_college_name',
    'min_year': 'ncaa_min_year',
    'max_year': 'ncaa_max_year',
    'clean_player_name' : 'ncaa_clean_full_name',
    'clean_team': 'clean_ncaa_college_name'
}
matches_review = nba_ncaa_matches.rename(columns = col_rename_dict)
matches_review.to_csv('./resolved_data/nba_ncaa_matches_review.csv', index = False)

# %%
matches_review.head()
# Out:
#         nba_id nba_first_name nba_last_name nba_birthdate nba_college_name  \
# 332368  202322           John          Wall    1990-09-06         Kentucky
# 363139  202323           Evan        Turner    1988-10-27       Ohio State
# 176738  202324        Derrick        Favors    1991-07-15     Georgia Tech
# 381231  202325         Wesley       Johnson    1987-07-11         Syracuse
# 332700  202326       DeMarcus       Cousins    1990-08-13         Kentucky
#
#        nba_country nba_draft_year nba_draft_round draftNumber  \
# 332368         USA           2010               1           1
# 363139         USA           2010               1           2
# 176738         USA           2010               1           3
# 381231         USA           2010               1           4
# 332700         USA           2010               1           5
#
#            nba_full_name  ... nba_clean_college_name college_token ncaa_id  \
# 332368         John Wall  ...               KENTUCKY      KENTUCKY   19599
# 363139       Evan Turner  ...             OHIO STATE          OHIO   13070
# 176738    Derrick Favors  ...           GEORGIA TECH       GEORGIA   10482
# 381231    Wesley Johnson  ...               SYRACUSE      SYRACUSE   37984
# 332700  DeMarcus Cousins  ...               KENTUCKY      KENTUCKY    9911
#
#           ncaa_full_name ncaa_college_name ncaa_min_year  ncaa_max_year  \
# 332368         John Wall          Kentucky          2010           2010
# 363139       Evan Turner          Ohio St.          2010           2010
# 176738    Derrick Favors      Georgia Tech          2010           2010
# 381231       Wes Johnson          Syracuse          2010           2010
# 332700  DeMarcus Cousins          Kentucky          2010           2010
#
#         ncaa_clean_full_name clean_ncaa_college_name fuzzy_name_score
# 332368             JOHN WALL                KENTUCKY              100
# 363139           EVAN TURNER                 OHIO ST              100
# 176738        DERRICK FAVORS            GEORGIA TECH              100
# 381231           WES JOHNSON                SYRACUSE               88
# 332700      DEMARCUS COUSINS                KENTUCKY              100
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Calculate Euclidean Distances for to find Similar Players

# %%
# load college player data
ncaa_data_raw = pd.read_csv('./resolved_data/player_data_college_latest_season.csv')

# add percentages
ncaa_data_raw['3p_pct'] = (ncaa_data_raw['3p_made'] / ncaa_data_raw['3p_attempted']) * 100
ncaa_data_raw['3p_pct'] = ncaa_data_raw['3p_pct'].fillna(0)
ncaa_data_raw['2p_pct'] = (ncaa_data_raw['2p_made'] / ncaa_data_raw['2p_attempted']) * 100
ncaa_data_raw['2p_pct'] = ncaa_data_raw['2p_pct'] .fillna(0)

# scale data
scaler = MinMaxScaler()
stats_of_interest = [
    'height', 
    'total_reb', 
    'assists', 
    'steals', 
    'blocks', 
    'shooting_pct',
    'points_scored',
    '3p_pct',
    '2p_pct',
    'shooting_pct'
]

ncaa_data = ncaa_data_raw[['ncaa_id', 'max_year'] + stats_of_interest].copy()
ncaa_data[stats_of_interest] = scaler.fit_transform(ncaa_data[stats_of_interest])

# get incoming prospects
incoming_prospects = ncaa_data[ncaa_data['max_year'] == 2025]

# get players to match to
ncaa_players_to_match_to = pd.merge(ncaa_data, nba_ncaa_matches['ncaa_id'].to_frame(), on = 'ncaa_id', how = 'inner')
ncaa_players_to_match_to = ncaa_players_to_match_to[ncaa_players_to_match_to['max_year'] != 2025]

# convert dfs to arrays 
incoming_prospects_arr = incoming_prospects.to_numpy()
ncaa_players_to_match_to_arr = ncaa_players_to_match_to.to_numpy()

# %%
incoming_prospects.head()
# Out:
#        ncaa_id  max_year    height  total_reb   assists    steals    blocks  \
# 23880    32016      2025  0.483333   0.155360  0.106667  0.225456  0.045644
# 23881    11675      2025  0.458333   0.089497  0.212721  0.108398  0.014625
# 23882    21738      2025  0.533333   0.157265  0.028672  0.082650  0.079763
# 23883    15748      2025  0.533333   0.472478  0.200721  0.256200  0.067477
# 23884    32041      2025  0.508333   0.170531  0.047881  0.201860  0.132557
#
#        shooting_pct  points_scored    3p_pct    2p_pct  shooting_pct
# 23880      0.551449       0.372628  0.361702  0.505495      0.551449
# 23881      0.550264       0.199518  0.421053  0.410256      0.550264
# 23882      0.563301       0.112352  0.000000  0.634921      0.563301
# 23883      0.572137       0.304519  0.347458  0.652174      0.572137
# 23884      0.583019       0.362624  0.380531  0.540984      0.583019

# %%
len(incoming_prospects)
# Out:
# 3673

# %%
ncaa_players_to_match_to.head()
# Out:
#    ncaa_id  max_year  height  total_reb   assists    steals    blocks  \
# 0    32811      2010     0.7   0.268380  0.111506  0.148750  0.098153
# 1    18618      2010     0.8   0.475346  0.072622  0.210981  0.341207
# 2    14293      2010     0.5   0.321181  0.626548  0.440357  0.065385
# 3     7422      2010     1.0   0.680724  0.085047  0.192150  0.660353
# 4    24405      2010     0.5   0.518763  0.151052  0.482271  0.100683
#
#    shooting_pct  points_scored    3p_pct    2p_pct  shooting_pct
# 0      0.478289       0.224003  0.000000  0.491018      0.478289
# 1      0.642495       0.332338  0.250000  0.673367      0.642495
# 2      0.515354       0.665206  0.360215  0.471875      0.515354
# 3      0.564810       0.373886  0.000000  0.562264      0.564810
# 4      0.500377       0.601520  0.349462  0.478659      0.500377

# %%
len(ncaa_players_to_match_to)
# Out:
# 401

# %%
np.linalg.norm(np.array([1,2,3]) - np.array([1,2,3]))
# Out:
# 0.0

# %%
similarity_results = []
for prospect in incoming_prospects_arr:
    prospect_id = prospect[0]
    prospect_stats = prospect[2:] # remove id and max year

    for target_player in ncaa_players_to_match_to_arr:
        target_player_id = target_player[0]
        target_stats = target_player[2:]

        # calculate euclidean distance
        euclidean_dist = np.linalg.norm(np.array(prospect_stats) - np.array(target_stats))

        tmp_res = {'prospect_ncaa_id': int(prospect_id), 'similar_player_ncaa_id': int(target_player_id), 'euclidean_distance': euclidean_dist}
        similarity_results.append(tmp_res)

similarity_results_df = pd.DataFrame(similarity_results)

# %%
# add similarity score
def reverse_min_max_scale(series):
    min_val = series.min()
    max_val = series.max()
    return 1 - ((series - min_val) / (max_val - min_val))

similarity_results_df['similarity_score'] = reverse_min_max_scale(similarity_results_df['euclidean_distance'])

# order df on similarity score
similarity_results_df_ordered = similarity_results_df.sort_values(by = ['prospect_ncaa_id', 'similarity_score'], ascending = False)
similarity_results_df_ordered['rank'] = similarity_results_df_ordered.groupby('prospect_ncaa_id')['similarity_score'].rank(method = 'first', ascending = False)

# %%
similarity_results_df_ordered[similarity_results_df_ordered['prospect_ncaa_id'] == 39094].to_csv('./test.csv')

# %%
similarity_results_df_ordered.to_csv('./player_similarity_results.csv', index = False)

# %%
len(similarity_results_df_ordered)
# Out:
# 1472873

# %% [markdown]
# ## Generate Similarity Review

# %%
similarity_results_df_ordered.head()
# Out:
#         prospect_ncaa_id  similar_player_ncaa_id  euclidean_distance  \
# 797260             39094                   20880            0.274481
# 797495             39094                   14382            0.329531
# 797420             39094                   19779            0.331741
# 797337             39094                   14094            0.336692
# 797560             39094                   20991            0.368759
#
#         similarity_score  rank
# 797260          0.851543   1.0
# 797495          0.816308   2.0
# 797420          0.814893   3.0
# 797337          0.811725   4.0
# 797560          0.791200   5.0

# %%
ncaa_review = ncaa_data_raw[['ncaa_id', 'player_name', 'team', 'pos_class'] + stats_of_interest].copy()

# %%
ncaa_review.head()
# Out:
#    ncaa_id     player_name               team  height  pos_class  height  \
# 0     8686      Dana Smith           Longwood  167.64     Wing F  167.64
# 1     5795   Carlos Strong  Boston University  106.68    Combo G  106.68
# 2    12966  Eulis Stephens      Detroit Mercy  137.16     Wing G  137.16
# 3     4471   Brett Gifford             Albany  350.52          C  350.52
# 4    37615  Valdas Sirutis  Boston University  228.60  Stretch 4  228.60
#
#    total_reb  assists  steals  blocks  shooting_pct  points_scored     3p_pct  \
# 0     7.0741   2.4074  0.8148  0.4815         53.76        17.5556  36.263736
# 1     4.5714   1.8000  1.6571  0.4000         60.93        10.8571  47.200000
# 2     1.9032   0.5806  0.3871  0.1290         55.91         3.5806  18.181818
# 3     3.3000   0.6000  0.4000  0.8333         46.77         2.0667   0.000000
# 4     2.4688   0.5938  0.2188  0.0625         43.49         2.0312  24.137931
#
#       2p_pct  shooting_pct
# 0  48.275862         53.76
# 1  47.794118         60.93
# 2  61.111111         55.91
# 3  47.540984         46.77
# 4  45.161290         43.49

# %%
ncaa_review = ncaa_data_raw[['ncaa_id', 'player_name', 'team', 'pos_class'] + stats_of_interest].copy()
similarity_review = pd.merge(similarity_results_df_ordered, ncaa_review, left_on = 'prospect_ncaa_id', right_on = 'ncaa_id', how = 'inner')
similarity_review = pd.merge(similarity_review, ncaa_review, left_on = 'similar_player_ncaa_id', right_on = 'ncaa_id', how = 'inner')
review_cols = {
    'prospect_ncaa_id': 'prospect_ncaa_id', 
    'similar_player_ncaa_id': 'similar_player_ncaa_id', 
    'euclidean_distance': 'euclidean_distance',
    'similarity_score': 'similarity_score', 
    'rank': 'rank', 
    'player_name_x': 'prospect_player_name', 
    'player_name_y': 'similar_player_player_name', 
    'team_x': 'prospect_team',
    'team_y': 'similar_player_team',
    'height_x': 'prospect_height', 
    'height_y': 'similar_player_height', 
    'pos_class_x': 'prospect_pos_class', 
    'pos_class_y': 'similar_player_pos_class', 
    'points_scored_x': 'prospect_points_scored', 
    'points_scored_y': 'similar_player_points_score',
    'total_reb_x': 'prospect_total_reb', 
    'total_reb_y': 'similar_player_total_reb',
    'assists_x': 'prospect_assists',
    'assists_y': 'similar_player_assists',
    'steals_x': 'prospect_steals', 
    'steals_y': 'similar_player_steals',
    'blocks_x': 'prospect_blocks', 
    'blocks_y': 'similar_player_blocks',
    'shooting_pct_x': 'prospect_shooting_pct', 
    'shooting_pct_y': 'similar_player_shooting_pct',
    '3p_pct_x': 'prospect_3p_pct',
    '3p_pct_y': 'similar_player_3p_pct',
    '2p_pct_x': 'prospect_2p_pct',    
    '2p_pct_y': 'similar_player_2p_pct'
}
similarity_review = similarity_review[list(review_cols.keys())].rename(columns = review_cols)
similarity_review = similarity_review[similarity_review['rank'] <= 3.0].sort_values(by = ['prospect_ncaa_id', 'rank'], ascending = True)

# %%
similarity_review.columns
# Out:
# Index(['prospect_ncaa_id', 'similar_player_ncaa_id', 'euclidean_distance',
#        'similarity_score', 'rank', 'prospect_player_name',
#        'similar_player_player_name', 'prospect_team', 'similar_player_team',
#        'prospect_height', 'similar_player_height', 'prospect_pos_class',
#        'similar_player_pos_class', 'prospect_points_scored',
#        'similar_player_points_score', 'prospect_total_reb',
#        'similar_player_total_reb', 'prospect_assists',
#        'similar_player_assists', 'prospect_steals', 'similar_player_steals',
#        'prospect_blocks', 'similar_player_blocks', 'prospect_shooting_pct',
#        'prospect_shooting_pct', 'similar_player_shooting_pct',
#        'similar_player_shooting_pct', 'prospect_3p_pct',
#        'similar_player_3p_pct', 'prospect_2p_pct', 'similar_player_2p_pct'],
#       dtype='object')

# %%
similarity_review.head()
# Out:
#         prospect_ncaa_id  similar_player_ncaa_id  euclidean_distance  \
# 128554                39                   26265            0.113780
# 40402                 39                    1791            0.204733
# 418721                39                   29224            0.205924
# 227724                52                   37108            0.099200
# 135899                52                   11768            0.108065
#
#         similarity_score  rank prospect_player_name  \
# 128554          0.954400   1.0         A.J. Hoggard
# 40402           0.896185   2.0         A.J. Hoggard
# 418721          0.895423   3.0         A.J. Hoggard
# 227724          0.963732   1.0           A.J. Lopez
# 135899          0.958058   2.0           A.J. Lopez
#
#        similar_player_player_name prospect_team similar_player_team  \
# 128554             Marquis Teague    Vanderbilt            Kentucky
# 40402             Andrew Harrison    Vanderbilt            Kentucky
# 418721               Nico Mannion    Vanderbilt             Arizona
# 227724               Tyler Dorsey         Maine              Oregon
# 135899              Dusty Hannahs         Maine            Arkansas
#
#         prospect_height  ...  prospect_blocks similar_player_blocks  \
# 128554           193.04  ...           0.2581                0.2750
# 40402            193.04  ...           0.2581                0.2051
# 418721           193.04  ...           0.2581                0.0000
# 227724           195.58  ...           0.1515                0.1026
# 135899           195.58  ...           0.1515                0.1111
#
#         prospect_shooting_pct  prospect_shooting_pct  \
# 128554                  45.21                  45.21
# 40402                   45.21                  45.21
# 418721                  45.21                  45.21
# 227724                  60.09                  60.09
# 135899                  60.09                  60.09
#
#         similar_player_shooting_pct  similar_player_shooting_pct  \
# 128554                        49.08                        49.08
# 40402                         53.13                        53.13
# 418721                        52.07                        52.07
# 227724                        60.49                        60.49
# 135899                        58.93                        58.93
#
#         prospect_3p_pct  similar_player_3p_pct  prospect_2p_pct  \
# 128554        27.368421              32.500000        39.898990
# 40402         27.368421              38.297872        39.898990
# 418721        27.368421              32.716049        39.898990
# 227724        39.694656              42.364532        52.261307
# 135899        39.694656              38.743455        52.261307
#
#         similar_player_2p_pct
# 128554              43.750000
# 40402               37.572254
# 418721              44.660194
# 227724              51.030928
# 135899              48.958333
#
# [5 rows x 31 columns]

# %%
similarity_review.to_csv('./similarity_review.csv', index = False)
